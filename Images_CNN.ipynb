# %% [markdown]
# <a href="https://colab.research.google.com/github/slmsshk/NEURAL-STYLE-TRANSFER/blob/main/Images_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# image
from numpy import *
from matplotlib.pyplot import *

# %%
im=plt.imread('/content/download.jfif')

# %%
255*2
# Out:
# 510

# %%
test_images = im.astype('float32') / 128

# %%
np.random.shuffle(test_images)

# %%
test_images.shape
# Out:
# (130, 195, 3)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Horizontally stacked subplots')
# ax1.plot(x, y)
# ax2.plot(x, -y)
ax1.imshow(test_images)
ax2.imshow(im)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
y=plt.imread('data:image/jpeg;base64,...')

# %%
z=plt.imread('https://www.google.com/images/branding/googlelogo/2x/googlelogo_light_color_92x30dp.png')

# %%
plt.imshow(z)

# %%
r = z[:, :, 3]

# %%
imshow(r,cmap=cm.gray)

# %%
t=y[100:156,250:310]

# %%
np.random.shuffle(y)

# %%
y.shape
# Out:
# (256, 334, 4)

# %%
t.shape
# Out:
# (56, 60, 4)

# %%
plt.imshow(t)

# %%
im.shape
# Out:
# (130, 195, 3)

# %%
130*195*3
# Out:
# 76050

# %%
760050/195/3
# Out:
# 1299.2307692307693

# %%
760050/3
# Out:
# 253350.0

# %%
253350.0/149
# Out:
# 1700.3355704697988

# %%
import time
from random import randint

# %%
while True:
  x=np.random.randint(0,100,76050)
  x=x.reshape(130, 195, 3)
  plt.imshow(x)
  plt.show()
  time.sleep(1)

# %%
im[0]

# %%
plt.imshow(im)
